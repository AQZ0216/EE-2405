# %% [markdown]
# # EE2405 Embedded System Lab Exam #2 Part 2
#
# **Please click on "Open in playground" at the upper-left corner to create a copy for you.**
#
# ---
#
# **Please fill in correct statements in the right of the codes to finish the scripts.**
# Data sample is generated with a quadratic function and we will train a regression model to fit the data.
# And we convert and interpret the trained model with a Tensorflow lite APIs.
#
# You can run the script again after you fill all the blank to check the outputs.
#
# ---
#
# The Method to Download the Jupyter Notebook:
# File > Download .ipynb

# %% [markdown]
# ## Import dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf
# Numpy is a math library
import numpy as np
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# math is Python's math library
import math

# %% [markdown]
# ## Generate Data

# %%
# We'll generate this many sample datapoints
############################################################
#@markdown Please fill in the number of samples (the sample should be large enough, but not too large for computation).
SAMPLES =  200#@param {type:"number"}
############################################################


############################################################
#@markdown Please fill in your student id, which is the random seed.
student_id = 106061151 #@param {type:"number"}
np.random.seed(student_id)
############################################################

# Generate a uniformly distributed set of random numbers
# in the range from 0 to 10
x_values = np.random.uniform(low=0, high=10, size=SAMPLES)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

############################################################
#@markdown Please fill in the statement to generate `y_values` with a quadratic function `y = x^2-5x+1`?
script = "y_values = x_values*x_values - 5*x_values +1" #@param {type:"string"}
exec(script)
############################################################

# Plot our data.
# The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Add some noise

# %%
# Add a small random number to each y value
y_values += np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Split our data

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Design a model

# %%
# We'll use Keras to create a simple model architecture
from tensorflow.keras import layers
model = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model.add(layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second layer may help the network learn more complex representations
model.add(layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model.add(layers.Dense(1))

# Compile the model using a standard optimizer and loss function for regression
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ## Train the model

# %%
# Train the model on our training data while validating on our validation set
model.fit(x_train, y_train, epochs=1000, batch_size=16,
          validation_data=(x_validate, y_validate))

print("Done!")
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 269.3561 - mae: 11.2326 - val_loss: 413.7575 - val_mae: 15.0697
# Epoch 2/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 296.9628 - mae: 11.1251 - val_loss: 404.4400 - val_mae: 14.9248
# Epoch 3/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 257.5421 - mae: 11.0430 - val_loss: 397.5334 - val_mae: 14.8214
# Epoch 4/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 276.2078 - mae: 10.9687 - val_loss: 388.9375 - val_mae: 14.6908
# Epoch 5/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 247.8396 - mae: 10.8874 - val_loss: 381.9137 - val_mae: 14.5820
# Epoch 6/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 251.6872 - mae: 10.8093 - val_loss: 373.2129 - val_mae: 14.4449
# Epoch 7/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 236.8628 - mae: 10.7293 - val_loss: 364.5372 - val_mae: 14.3054
# Epoch 8/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 269.2366 - mae: 10.6433 - val_loss: 353.6855 - val_mae: 14.1270
# Epoch 9/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 229.4341 - mae: 10.5521 - val_loss: 345.1858 - val_mae: 13.9970
# Epoch 10/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 236.5491 - mae: 10.4719 - val_loss: 334.8057 - val_mae: 13.8402
# Epoch 11/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 228.1459 - mae: 10.3740 - val_loss: 324.3549 - val_mae: 13.7032
# Epoch 12/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 221.7815 - mae: 10.2708 - val_loss: 312.8500 - val_mae: 13.5642
# Epoch 13/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 197.0143 - mae: 10.1709 - val_loss: 302.4720 - val_mae: 13.4409
# Epoch 14/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 204.1005 - mae: 10.0744 - val_loss: 291.3503 - val_mae: 13.3036
# Epoch 15/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 185.2676 - mae: 9.9959 - val_loss: 281.6208 - val_mae: 13.1781
# Epoch 16/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 189.3463 - mae: 9.9128 - val_loss: 270.6001 - val_mae: 13.0326
# Epoch 17/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 172.7416 - mae: 9.8356 - val_loss: 260.5479 - val_mae: 12.9135
# Epoch 18/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 170.3474 - mae: 9.7831 - val_loss: 250.3073 - val_mae: 12.7854
# Epoch 19/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 160.3049 - mae: 9.7601 - val_loss: 242.0598 - val_mae: 12.6782
# Epoch 20/1000
# 8/8 [==============================] - 0s 5ms/step - loss:
1000
# 8/8 [==============================] - 0s 5ms/step - loss: 113.5797 - mae: 9.1892 - val_loss: 151.7586 - val_mae: 11.1841
# Epoch 52/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 110.1210 - mae: 9.1980 - val_loss: 151.3733 - val_mae: 11.1658
# Epoch 53/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 110.0835 - mae: 9.1770 - val_loss: 151.3486 - val_mae: 11.1469
# Epoch 54/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 108.5805 - mae: 9.1267 - val_loss: 150.6735 - val_mae: 11.1303
# Epoch 55/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 113.0234 - mae: 9.1332 - val_loss: 150.1145 - val_mae: 11.1107
# Epoch 56/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 110.2310 - mae: 9.0908 - val_loss: 149.3499 - val_mae: 11.0928
# Epoch 57/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 109.2354 - mae: 9.0913 - val_loss: 149.0694 - val_mae: 11.0734
# Epoch 58/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 109.1477 - mae: 9.0763 - val_loss: 149.0196 - val_mae: 11.0520
# Epoch 59/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 108.5145 - mae: 9.0245 - val_loss: 148.2929 - val_mae: 11.0337
# Epoch 60/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 108.2732 - mae: 9.0237 - val_loss: 147.8264 - val_mae: 11.0161
# Epoch 61/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 106.1879 - mae: 9.0105 - val_loss: 147.3595 - val_mae: 10.9970
# Epoch 62/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 107.9531 - mae: 8.9613 - val_loss: 146.5253 - val_mae: 10.9801
# Epoch 63/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 106.3407 - mae: 8.9816 - val_loss: 146.1088 - val_mae: 10.9594
# Epoch 64/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 102.0732 - mae: 8.9538 - val_loss: 145.9319 - val_mae: 10.9396
# Epoch 65/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 107.7096 - mae: 8.9223 - val_loss: 145.1172 - val_mae: 10.9202
# Epoch 66/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 104.2313 - mae: 8.8914 - val_loss: 144.4676 - val_mae: 10.9025
# Epoch 67/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 107.1057 - mae: 8.9084 - val_loss: 144.3696 - val_mae: 10.8825
# Epoch 68/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 105.8828 - mae: 8.8810 - val_loss: 144.1261 - val_mae: 10.8648
# Epoch 69/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 105.4722 - mae: 8.8354 - val_loss: 143.4098 - val_mae: 10.8494
# Epoch 70/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 103.1404 - mae: 8.8447 - val_loss: 143.4905 - val_mae: 10.8316
# Epoch 71/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 100.0437 - mae: 8.8165 - val_loss: 143.1854 - val_mae: 10.8142
# Epoch 72/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 107.2246 - mae: 8.7827 - val_loss: 142.3279 - val_mae: 10.7959
# Epoch 73/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 102.9622 - mae: 8.7641 - val_loss: 141.8849 - val_mae: 10.7765
# Epoch 74/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 100.9713 - mae: 8.7392 - val_loss: 141.6180 - val_mae: 10.7581
# Epoch 75/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 99.9924 - mae: 8.7127 - val_loss: 141.2854 - val_mae: 10.7395
# Epoch 76/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 99.8634 - mae: 8.6837 - val_loss: 140.8800 - val_mae: 10.7195
# Epoch 77/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 98.7059 - mae: 8.6515 - val_loss: 140.5211 - val_mae: 10.7029
# Epoch 78/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 100.7111 - mae: 8.6392 - val_loss: 140.0372 - val_mae: 10.6832
# Epoch 79/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 101.0333 - mae: 8.6256 - val_loss: 139.8667 - val_mae: 10.6649
# Epoch 80/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 107.5091 - mae: 8.5773 - val_loss: 138.7443 - val_mae: 10.6483
# Epoch 81/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 98.6996 - mae: 8.6090 - val_loss: 138.6550 - val_mae: 10.6301
# Epoch 82/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 97.3512 - mae: 8.5766 - val_loss: 138.4259 - val_mae: 10.6128
# Epoch 83/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 99.3915 - mae: 8.5346 - val_loss: 138.1489 - val_mae: 10.5938
# Epoch 84/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 99.4013 - mae: 8.5001 - val_loss: 136.9650 - val_mae: 10.5750
# Epoch 85/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 98.4788 - mae: 8.5093 - val_loss: 136.1050 - val_mae: 10.5549
# Epoch 86/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 96.6707 - mae: 8.5139 - val_loss: 135.6945 - val_mae: 10.5327
# Epoch 87/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 96.5674 - mae: 8.4882 - val_loss: 135.2630 - val_mae: 10.5118
# Epoch 88/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 98.6042 - mae: 8.4405 - val_loss: 134.4543 - val_mae: 10.4898
# Epoch 89/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 95.2076 - mae: 8.4586 - val_loss: 134.2021 - val_mae: 10.4725
# Epoch 90/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 96.5193 - mae: 8.4207 - val_loss: 133.5653 - val_mae: 10.4504
# Epoch 91/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 94.3838 - mae: 8.3933 - val_loss: 133.2164 - val_mae: 10.4271
# Epoch 92/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 97.4046 - mae: 8.3764 - val_loss: 132.3623 - val_mae: 10.4028
# Epoch 93/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 92.8815 - mae: 8.3613 - val_loss: 132.0533 - val_mae: 10.3768
# Epoch 94/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 93.7483 - mae: 8.3226 - val_loss: 131.6641 - val_mae: 10.3539
# Epoch 95/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 92.0016 - mae: 8.2886 - val_loss: 130.9488 - val_mae: 10.3287
# Epoch 96/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 92.6494 - mae: 8.2699 - val_loss: 130.5304 - val_mae: 10.3045
# Epoch 97/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 92.0441 - mae: 8.2233 - val_loss: 129.8273 - val_mae: 10.2783
# Epoch 98/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 93.3379 - mae: 8.1999 - val_loss: 128.5821 - val_mae: 10.2485
# Epoch 99/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 91.3487 - mae: 8.1975 - val_loss: 128.3457 - val_mae: 10.2218
# Epoch 100/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 89.3677 - mae: 8.1717 - val_loss: 128.1817 - val_mae: 10.1967
# Epoch 101/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 90.8336 - mae: 8.1112 - val_loss: 127.1161 - val_mae: 10.1690
# Epoch 102/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 91.1530 - mae: 8.1462 - val_loss: 126.5959 - val_mae: 10.1420
# Epoch 103/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 89.1515 - mae: 8.0942 - val_loss: 126.3049 - val_mae: 10.1176
# Epoch 104/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 87.5184 - mae: 8.0739 - val_loss: 125.6887 - val_mae: 10.0907
# Epoch 105/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 86.9889 - mae: 8.0261 - val_loss: 124.9741 - val_mae: 10.0615
# Epoch 106/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 88.3677 - mae: 7.9757 - val_loss: 123.5886 - val_mae: 10.0306
# Epoch 107/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 86.8937 - mae: 7.9979 - val_loss: 123.1531 - val_mae: 10.0029
# Epoch 108/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 85.2372 - mae: 7.9557 - val_loss: 122.6884 - val_mae: 9.9760
# Epoch 109/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 86.1699 - mae: 7.9279 - val_loss: 122.4131 - val_mae: 9.9507
# Epoch 110/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 87.8011 - mae: 7.8964 - val_loss: 121.6832 - val_mae: 9.9250
# Epoch 111/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 82.8067 - mae: 7.8548 - val_loss: 120.9631 - val_mae: 9.8988
# Epoch 112/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 82.9708 - mae: 7.8542 - val_loss: 120.2733 - val_mae: 9.8678
# Epoch 113/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 86.5465 - mae: 7.8172 - val_loss: 119.2215 - val_mae: 9.8308
# Epoch 114/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 82.7528 - mae: 7.8042 - val_loss: 118.6668 - val_mae: 9.7995
# Epoch 115/1000
# 8/8 [==============================] - 0s 6ms/step - loss:
1000
# 8/8 [==============================] - 0s 5ms/step - loss: 44.0230 - mae: 5.3295 - val_loss: 66.1391 - val_mae: 7.0266
# Epoch 180/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 40.7724 - mae: 5.3681 - val_loss: 65.8439 - val_mae: 6.9937
# Epoch 181/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 44.6541 - mae: 5.2892 - val_loss: 64.4370 - val_mae: 6.9205
# Epoch 182/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 38.8129 - mae: 5.2759 - val_loss: 63.6441 - val_mae: 6.8678
# Epoch 183/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 42.4537 - mae: 5.2319 - val_loss: 62.9456 - val_mae: 6.8173
# Epoch 184/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 39.5839 - mae: 5.1652 - val_loss: 62.0985 - val_mae: 6.7621
# Epoch 185/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 37.6509 - mae: 5.1345 - val_loss: 61.5677 - val_mae: 6.7213
# Epoch 186/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 36.9872 - mae: 5.0581 - val_loss: 60.5277 - val_mae: 6.6615
# Epoch 187/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 36.1151 - mae: 5.0465 - val_loss: 60.1126 - val_mae: 6.6202
# Epoch 188/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 36.4519 - mae: 4.9565 - val_loss: 58.5873 - val_mae: 6.5388
# Epoch 189/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 35.9475 - mae: 4.9432 - val_loss: 57.6274 - val_mae: 6.4754
# Epoch 190/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 36.8644 - mae: 4.9021 - val_loss: 56.6828 - val_mae: 6.4145
# Epoch 191/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 36.1057 - mae: 4.8575 - val_loss: 56.0718 - val_mae: 6.3741
# Epoch 192/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 33.9506 - mae: 4.8232 - val_loss: 55.6613 - val_mae: 6.3396
# Epoch 193/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 34.1287 - mae: 4.7482 - val_loss: 54.5572 - val_mae: 6.2739
# Epoch 194/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 34.3769 - mae: 4.7036 - val_loss: 53.4780 - val_mae: 6.2042
# Epoch 195/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 32.2353 - mae: 4.6711 - val_loss: 52.5002 - val_mae: 6.1414
# Epoch 196/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 31.7136 - mae: 4.6349 - val_loss: 52.1089 - val_mae: 6.1074
# Epoch 197/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 30.6696 - mae: 4.5782 - val_loss: 51.5454 - val_mae: 6.0632
# Epoch 198/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 30.3250 - mae: 4.5365 - val_loss: 50.8879 - val_mae: 6.0170
# Epoch 199/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 29.8282 - mae: 4.4489 - val_loss: 50.0166 - val_mae: 5.9624
# Epoch 200/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 30.0354 - mae: 4.4300 - val_loss: 49.3831 - val_mae: 5.9165
# Epoch 201/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 30.0444 - mae: 4.3540 - val_loss: 48.2741 - val_mae: 5.8482
# Epoch 202/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 29.8008 - mae: 4.3084 - val_loss: 47.0509 - val_mae: 5.7664
# Epoch 203/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 27.5028 - mae: 4.3112 - val_loss: 46.6116 - val_mae: 5.7342
# Epoch 204/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 29.6721 - mae: 4.2462 - val_loss: 45.7778 - val_mae: 5.6748
# Epoch 205/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 28.4223 - mae: 4.1558 - val_loss: 44.4979 - val_mae: 5.5815
# Epoch 206/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 27.0651 - mae: 4.1797 - val_loss: 43.6652 - val_mae: 5.5278
# Epoch 207/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 25.7371 - mae: 4.1432 - val_loss: 43.4921 - val_mae: 5.5037
# Epoch 208/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 26.4097 - mae: 4.0499 - val_loss: 42.4288 - val_mae: 5.4335
# Epoch 209/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 24.5022 - mae: 4.0161 - val_loss: 41.6615 - val_mae: 5.3762
# Epoch 210/1000
# 8/8 [==============================] - 0s 5ms/step - loss:
1000
# 8/8 [==============================] - 0s 5ms/step - loss: 7.2130 - mae: 2.1154 - val_loss: 9.9234 - val_mae: 2.4829
# Epoch 276/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 7.5234 - mae: 2.0821 - val_loss: 9.1291 - val_mae: 2.4867
# Epoch 277/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.9037 - mae: 2.1002 - val_loss: 9.4493 - val_mae: 2.4429
# Epoch 278/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6797 - mae: 2.0391 - val_loss: 8.8196 - val_mae: 2.4624
# Epoch 279/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.7051 - mae: 2.0843 - val_loss: 9.4739 - val_mae: 2.4000
# Epoch 280/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.2900 - mae: 2.0090 - val_loss: 8.7204 - val_mae: 2.3749
# Epoch 281/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 6.3759 - mae: 2.0336 - val_loss: 8.4433 - val_mae: 2.3560
# Epoch 282/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.5381 - mae: 1.9880 - val_loss: 8.1253 - val_mae: 2.3499
# Epoch 283/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.6894 - mae: 1.9866 - val_loss: 7.9561 - val_mae: 2.3363
# Epoch 284/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 5.9290 - mae: 1.9797 - val_loss: 8.2111 - val_mae: 2.2825
# Epoch 285/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 6.1224 - mae: 1.9844 - val_loss: 8.2662 - val_mae: 2.2638
# Epoch 286/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.7249 - mae: 1.9138 - val_loss: 8.9386 - val_mae: 2.2697
# Epoch 287/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.8100 - mae: 1.9090 - val_loss: 7.6340 - val_mae: 2.2098
# Epoch 288/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.5190 - mae: 1.8982 - val_loss: 8.3845 - val_mae: 2.2155
# Epoch 289/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.7374 - mae: 1.8623 - val_loss: 7.2421 - val_mae: 2.1710
# Epoch 290/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.3536 - mae: 1.8746 - val_loss: 7.9043 - val_mae: 2.1721
# Epoch 291/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 5.2402 - mae: 1.8403 - val_loss: 7.6442 - val_mae: 2.1534
# Epoch 292/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.2638 - mae: 1.8320 - val_loss: 7.2840 - val_mae: 2.1297
# Epoch 293/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.3580 - mae: 1.8233 - val_loss: 7.8807 - val_mae: 2.1406
# Epoch 294/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.0164 - mae: 1.7634 - val_loss: 6.5976 - val_mae: 2.0871
# Epoch 295/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 5.1603 - mae: 1.8187 - val_loss: 7.1579 - val_mae: 2.0836
# Epoch 296/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.7788 - mae: 1.7647 - val_loss: 6.8424 - val_mae: 2.0574
# Epoch 297/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.8452 - mae: 1.7681 - val_loss: 6.6326 - val_mae: 2.0329
# Epoch 298/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 4.8714 - mae: 1.7648 - val_loss: 6.7272 - val_mae: 2.0260
# Epoch 299/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.4761 - mae: 1.7177 - val_loss: 6.8387 - val_mae: 2.0195
# Epoch 300/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 5.0981 - mae: 1.7083 - val_loss: 5.8478 - val_mae: 1.9900
# Epoch 301/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.8097 - mae: 1.7270 - val_loss: 5.7468 - val_mae: 1.9502
# Epoch 302/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.3852 - mae: 1.7006 - val_loss: 6.1213 - val_mae: 1.9485
# Epoch 303/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.4039 - mae: 1.7136 - val_loss: 6.5764 - val_mae: 1.9644
# Epoch 304/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.3718 - mae: 1.6584 - val_loss: 6.0546 - val_mae: 1.9259
# Epoch 305/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.5001 - mae: 1.6480 - val_loss: 5.9563 - val_mae: 1.9114
# Epoch 306/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4.0799 - mae: 1.6440 - val_loss: 5.4736 - val_mae: 1.8667
# Epoch 307/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 4
1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.8626 - mae: 1.3634 - val_loss: 3.7186 - val_mae: 1.4963
# Epoch 342/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.8775 - mae: 1.3097 - val_loss: 3.5391 - val_mae: 1.5116
# Epoch 343/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.8801 - mae: 1.3439 - val_loss: 3.6482 - val_mae: 1.4663
# Epoch 344/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.7437 - mae: 1.3250 - val_loss: 4.1028 - val_mae: 1.5173
# Epoch 345/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.7991 - mae: 1.3204 - val_loss: 3.9926 - val_mae: 1.4997
# Epoch 346/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.7792 - mae: 1.3172 - val_loss: 4.2905 - val_mae: 1.5341
# Epoch 347/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.6906 - mae: 1.3076 - val_loss: 3.9109 - val_mae: 1.4820
# Epoch 348/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 2.7175 - mae: 1.2995 - val_loss: 3.5243 - val_mae: 1.4316
# Epoch 349/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 2.5814 - mae: 1.2727 - val_loss: 3.2572 - val_mae: 1.4680
# Epoch 350/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.6481 - mae: 1.2674 - val_loss: 3.8528 - val_mae: 1.4661
# Epoch 351/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.5518 - mae: 1.2477 - val_loss: 3.1914 - val_mae: 1.4564
# Epoch 352/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.4958 - mae: 1.2582 - val_loss: 3.2296 - val_mae: 1.4043
# Epoch 353/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.5284 - mae: 1.2561 - val_loss: 3.2334 - val_mae: 1.3979
# Epoch 354/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.3330 - mae: 1.2178 - val_loss: 4.0868 - val_mae: 1.4867
# Epoch 355/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.5219 - mae: 1.2292 - val_loss: 3.6522 - val_mae: 1.4216
# Epoch 356/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.3906 - mae: 1.2269 - val_loss: 3.2624 - val_mae: 1.3669
# Epoch 357/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 2.5217 - mae: 1.2213 - val_loss: 3.0437 - val_mae: 1.3606
# Epoch 358/1000
# ...
# Epoch 880/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9946 - mae: 0.8229 - val_loss: 1.8192 - val_mae: 1.0806
# Epoch 881/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0309 - mae: 0.8189 - val_loss: 1.3490 - val_mae: 0.8721
# Epoch 882/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8295 - mae: 0.7618 - val_loss: 1.5191 - val_mae: 0.9511
# Epoch 883/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8891 - mae: 0.7788 - val_loss: 1.6542 - val_mae: 1.0296
# Epoch 884/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9072 - mae: 0.7872 - val_loss: 1.3801 - val_mae: 0.8088
# Epoch 885/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8872 - mae: 0.7822 - val_loss: 1.3926 - val_mae: 0.9055
# Epoch 886/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9390 - mae: 0.7876 - val_loss: 1.9617 - val_mae: 1.1178
# Epoch 887/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9567 - mae: 0.7713 - val_loss: 1.7840 - val_mae: 0.9907
# Epoch 888/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0762 - mae: 0.8495 - val_loss: 1.3718 - val_mae: 0.8901
# Epoch 889/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9073 - mae: 0.7873 - val_loss: 1.4581 - val_mae: 0.9325
# Epoch 890/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9447 - mae: 0.7975 - val_loss: 1.3033 - val_mae: 0.8478
# Epoch 891/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8410 - mae: 0.7647 - val_loss: 1.2822 - val_mae: 0.8384
# Epoch 892/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9323 - mae: 0.7802 - val_loss: 1.2438 - val_mae: 0.8030
# Epoch 893/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9222 - mae: 0.8015 - val_loss: 1.3073 - val_mae: 0.8017
# Epoch 894/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9802 - mae: 0.7983 - val_loss: 1.2499 - val_mae: 0.8311
# Epoch 895/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8694 - mae: 0.7631 - val_loss: 1.3731 - val_mae: 0.9012
# Epoch 896/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9568 - mae: 0.8109 - val_loss: 1.2790 - val_mae: 0.8428
# Epoch 897/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9169 - mae: 0.7807 - val_loss: 1.2771 - val_mae: 0.8285
# Epoch 898/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9118 - mae: 0.7743 - val_loss: 1.2838 - val_mae: 0.8337
# Epoch 899/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9436 - mae: 0.7633 - val_loss: 1.5260 - val_mae: 0.8727
# Epoch 900/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9903 - mae: 0.8117 - val_loss: 1.2656 - val_mae: 0.8121
# Epoch 901/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9001 - mae: 0.7836 - val_loss: 1.3996 - val_mae: 0.8970
# Epoch 902/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9402 - mae: 0.7806 - val_loss: 1.6925 - val_mae: 1.0368
# Epoch 903/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0404 - mae: 0.8114 - val_loss: 1.2605 - val_mae: 0.8269
# Epoch 904/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8925 - mae: 0.7725 - val_loss: 1.3924 - val_mae: 0.9098
# Epoch 905/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9397 - mae: 0.8023 - val_loss: 1.3061 - val_mae: 0.8756
# Epoch 906/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8923 - mae: 0.7819 - val_loss: 1.3064 - val_mae: 0.7980
# Epoch 907/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9955 - mae: 0.8214 - val_loss: 1.5273 - val_mae: 0.9748
# Epoch 908/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8816 - mae: 0.7779 - val_loss: 1.6090 - val_mae: 0.9986
# Epoch 909/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9367 - mae: 0.7819 - val_loss: 1.3287 - val_mae: 0.8025
# Epoch 910/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9116 - mae: 0.7744 - val_loss: 1.2523 - val_mae: 0.8191
# Epoch 911/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8669 - mae: 0.7709 - val_loss: 1.2848 - val_mae: 0.8278
# Epoch 912/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0001 - mae: 0.7747 - val_loss: 1.3579 - val_mae: 0.8082
# Epoch 913/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0304 - mae: 0.8466 - val_loss: 1.5130 - val_mae: 0.8619
# Epoch 914/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9523 - mae: 0.7982 - val_loss: 1.3071 - val_mae: 0.8468
# Epoch 915/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9471 - mae: 0.7893 - val_loss: 1.2990 - val_mae: 0.8321
# Epoch 916/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8814 - mae: 0.7723 - val_loss: 1.6070 - val_mae: 0.9982
# Epoch 917/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9420 - mae: 0.7748 - val_loss: 1.2841 - val_mae: 0.8736
# Epoch 918/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9450 - mae: 0.8205 - val_loss: 1.4164 - val_mae: 0.9308
# Epoch 919/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9098 - mae: 0.7929 - val_loss: 1.2583 - val_mae: 0.7985
# Epoch 920/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9942 - mae: 0.8128 - val_loss: 1.2938 - val_mae: 0.8015
# Epoch 921/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8886 - mae: 0.7774 - val_loss: 1.2848 - val_mae: 0.7994
# Epoch 922/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9281 - mae: 0.7795 - val_loss: 1.4299 - val_mae: 0.9347
# Epoch 923/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0198 - mae: 0.7931 - val_loss: 1.2437 - val_mae: 0.8151
# Epoch 924/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9232 - mae: 0.7756 - val_loss: 1.3073 - val_mae: 0.7982
# Epoch 925/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9025 - mae: 0.7815 - val_loss: 1.4368 - val_mae: 0.9231
# Epoch 926/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9101 - mae: 0.7718 - val_loss: 1.3409 - val_mae: 0.8782
# Epoch 927/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8720 - mae: 0.7741 - val_loss: 1.5803 - val_mae: 1.0004
# Epoch 928/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9471 - mae: 0.8113 - val_loss: 1.3411 - val_mae: 0.8759
# Epoch 929/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9474 - mae: 0.7767 - val_loss: 1.3100 - val_mae: 0.8007
# Epoch 930/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9106 - mae: 0.7845 - val_loss: 1.2674 - val_mae: 0.8282
# Epoch 931/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8982 - mae: 0.7737 - val_loss: 1.3065 - val_mae: 0.8343
# Epoch 932/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9557 - mae: 0.7823 - val_loss: 1.6006 - val_mae: 0.9925
# Epoch 933/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9091 - mae: 0.7895 - val_loss: 1.2403 - val_mae: 0.8145
# Epoch 934/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9496 - mae: 0.8086 - val_loss: 1.4663 - val_mae: 0.9425
# Epoch 935/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9126 - mae: 0.7697 - val_loss: 1.2540 - val_mae: 0.7998
# Epoch 936/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9026 - mae: 0.7811 - val_loss: 1.8553 - val_mae: 1.0930
# Epoch 937/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9910 - mae: 0.8202 - val_loss: 1.2554 - val_mae: 0.8032
# Epoch 938/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8767 - mae: 0.7567 - val_loss: 1.2705 - val_mae: 0.8192
# Epoch 939/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8856 - mae: 0.7805 - val_loss: 1.7899 - val_mae: 1.0672
# Epoch 940/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9152 - mae: 0.7793 - val_loss: 1.2866 - val_mae: 0.8471
# Epoch 941/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9552 - mae: 0.7737 - val_loss: 1.4217 - val_mae: 0.8211
# Epoch 942/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9453 - mae: 0.7935 - val_loss: 1.3233 - val_mae: 0.8129
# Epoch 943/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8541 - mae: 0.7720 - val_loss: 1.8370 - val_mae: 1.0838
# Epoch 944/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9475 - mae: 0.7802 - val_loss: 1.3364 - val_mae: 0.8726
# Epoch 945/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8624 - mae: 0.7585 - val_loss: 1.4990 - val_mae: 0.9441
# Epoch 946/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0123 - mae: 0.8177 - val_loss: 1.3034 - val_mae: 0.8444
# Epoch 947/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8686 - mae: 0.7665 - val_loss: 1.2953 - val_mae: 0.8075
# Epoch 948/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8845 - mae: 0.7795 - val_loss: 1.2524 - val_mae: 0.8151
# Epoch 949/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9994 - mae: 0.8281 - val_loss: 1.2844 - val_mae: 0.8085
# Epoch 950/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8858 - mae: 0.7694 - val_loss: 1.3273 - val_mae: 0.8584
# Epoch 951/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9744 - mae: 0.8116 - val_loss: 1.2904 - val_mae: 0.8291
# Epoch 952/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9493 - mae: 0.7950 - val_loss: 1.4485 - val_mae: 0.8375
# Epoch 953/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9269 - mae: 0.7979 - val_loss: 1.2560 - val_mae: 0.8227
# Epoch 954/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8800 - mae: 0.7752 - val_loss: 1.3841 - val_mae: 0.8825
# Epoch 955/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9861 - mae: 0.8052 - val_loss: 1.2503 - val_mae: 0.8022
# Epoch 956/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9278 - mae: 0.8105 - val_loss: 1.2810 - val_mae: 0.8170
# Epoch 957/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8961 - mae: 0.7851 - val_loss: 1.3312 - val_mae: 0.8475
# Epoch 958/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9710 - mae: 0.8198 - val_loss: 1.5265 - val_mae: 0.9528
# Epoch 959/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9582 - mae: 0.7871 - val_loss: 1.4204 - val_mae: 0.9173
# Epoch 960/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9209 - mae: 0.7752 - val_loss: 1.3965 - val_mae: 0.8998
# Epoch 961/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9216 - mae: 0.7877 - val_loss: 1.3477 - val_mae: 0.8086
# Epoch 962/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9124 - mae: 0.7964 - val_loss: 1.7453 - val_mae: 1.0305
# Epoch 963/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9276 - mae: 0.7828 - val_loss: 1.3552 - val_mae: 0.8118
# Epoch 964/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9736 - mae: 0.8144 - val_loss: 1.5711 - val_mae: 0.9799
# Epoch 965/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9786 - mae: 0.7920 - val_loss: 1.3833 - val_mae: 0.8132
# Epoch 966/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0080 - mae: 0.8260 - val_loss: 1.6217 - val_mae: 1.0062
# Epoch 967/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9187 - mae: 0.7741 - val_loss: 1.4082 - val_mae: 0.9131
# Epoch 968/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8837 - mae: 0.7737 - val_loss: 1.4363 - val_mae: 0.9338
# Epoch 969/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8983 - mae: 0.7863 - val_loss: 1.2552 - val_mae: 0.8171
# Epoch 970/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9494 - mae: 0.7855 - val_loss: 1.4607 - val_mae: 0.9577
# Epoch 971/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8670 - mae: 0.7742 - val_loss: 1.3316 - val_mae: 0.7997
# Epoch 972/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0476 - mae: 0.8405 - val_loss: 1.3232 - val_mae: 0.8515
# Epoch 973/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8913 - mae: 0.7859 - val_loss: 1.2844 - val_mae: 0.8294
# Epoch 974/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8773 - mae: 0.7797 - val_loss: 1.4205 - val_mae: 0.8816
# Epoch 975/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9748 - mae: 0.7966 - val_loss: 1.5415 - val_mae: 0.9576
# Epoch 976/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9644 - mae: 0.7674 - val_loss: 1.4014 - val_mae: 0.8976
# Epoch 977/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9263 - mae: 0.7841 - val_loss: 1.2549 - val_mae: 0.8114
# Epoch 978/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8570 - mae: 0.7447 - val_loss: 1.2863 - val_mae: 0.7947
# Epoch 979/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9364 - mae: 0.7975 - val_loss: 1.2832 - val_mae: 0.8421
# Epoch 980/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8583 - mae: 0.7643 - val_loss: 1.4047 - val_mae: 0.9021
# Epoch 981/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9095 - mae: 0.7753 - val_loss: 1.6173 - val_mae: 1.0014
# Epoch 982/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9508 - mae: 0.7689 - val_loss: 1.2715 - val_mae: 0.8303
# Epoch 983/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8406 - mae: 0.7619 - val_loss: 1.4471 - val_mae: 0.9045
# Epoch 984/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0051 - mae: 0.8020 - val_loss: 1.3332 - val_mae: 0.8010
# Epoch 985/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0483 - mae: 0.8076 - val_loss: 1.6606 - val_mae: 1.0314
# Epoch 986/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9244 - mae: 0.7831 - val_loss: 1.2697 - val_mae: 0.8287
# Epoch 987/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8975 - mae: 0.7701 - val_loss: 1.5464 - val_mae: 0.8794
# Epoch 988/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8913 - mae: 0.7954 - val_loss: 1.3225 - val_mae: 0.8692
# Epoch 989/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8954 - mae: 0.7736 - val_loss: 1.4002 - val_mae: 0.8168
# Epoch 990/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0545 - mae: 0.8216 - val_loss: 1.2829 - val_mae: 0.7935
# Epoch 991/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0222 - mae: 0.8079 - val_loss: 1.3542 - val_mae: 0.8946
# Epoch 992/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9132 - mae: 0.7770 - val_loss: 1.3069 - val_mae: 0.8616
# Epoch 993/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9626 - mae: 0.7880 - val_loss: 1.3528 - val_mae: 0.8039
# Epoch 994/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9339 - mae: 0.7910 - val_loss: 1.3842 - val_mae: 0.8142
# Epoch 995/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9178 - mae: 0.7848 - val_loss: 1.5846 - val_mae: 0.9788
# Epoch 996/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9060 - mae: 0.7736 - val_loss: 1.5142 - val_mae: 0.9700
# Epoch 997/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9107 - mae: 0.7926 - val_loss: 1.2449 - val_mae: 0.8129
# Epoch 998/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9337 - mae: 0.7668 - val_loss: 1.4848 - val_mae: 0.8378
# Epoch 999/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8974 - mae: 0.7861 - val_loss: 1.3106 - val_mae: 0.7970
# Epoch 1000/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9130 - mae: 0.7853 - val_loss: 1.2885 - val_mae: 0.8179
# Done!

# %% [markdown]
# ## Convert the Tensorflow Model to Tensorflow Lite Model

# %%
# Convert the model to the TensorFlow Lite format with quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)
# Out:
# 2532

# %% [markdown]
# ## Predict

# %% [markdown]
# ### Predict with Tensorflow Model

# %%
# Use the model to make predictions from our test data

############################################################
#@markdown How to use the model to predict the result with the test data (`x_test`) and save the result in a variable `predictions`?
script = "predictions = model.predict(x_test)" #@param {type:"string"}
exec(script)
############################################################

# %% [markdown]
# ### Predict with Tensorflow Lite Model

# %%
# Use the Tensorflow lite model to make interfences from our test data
#@markdown Please choose and fill in correct code statements from one of the following:
#@markdown 1. interpreter.invoke() 
#@markdown 2. interpreter_input().fill(x_test[i])
#@markdown 3. interpreter = tf.lite.Interpreter('model.tflite')
#@markdown 4. interpreter_predictions[i] = interpreter_output()[0]
#@markdown 5. interpreter_output = interpreter.tensor(interpreter.get_output_details()[0]["index"])
#@markdown 6. interpreter_input = interpreter.tensor(interpreter.get_input_details()[0]["index"])

############################################################
# Instantiate an interpreter for the TFLite model
#@markdown Which is the statement to instantiate an interpreter with a TFLite Model named `model.tflite`?
script_1 = "interpreter = tf.lite.Interpreter('model.tflite')" #@param {type:"string"}
exec(script_1)
############################################################

# Allocate memory for the model
interpreter.allocate_tensors()

############################################################
# Get the input tensors so we can feed in values 
#@markdown Which is the statement to get input sensors?
script_2 = "interpreter_input = interpreter.tensor(interpreter.get_input_details()[0][\"index\"])" #@param {type:"string"}
exec(script_2)
############################################################

############################################################
# Get the output tensors so we can get the results
#@markdown Which is the statement to get output sensors?
script_3 = "interpreter_output = interpreter.tensor(interpreter.get_output_details()[0][\"index\"])" #@param {type:"string"}
exec(script_3)
############################################################

# Create arrays to store the results
interpreter_predictions = np.empty(x_test.size)

# Run each model's interpreter for each value and store the results in arrays
for i in range(x_test.size):
  ############################################################
  #@markdown Which is the statement to fill the input of the interpreter with `x_test[i]`?
  script_4 = "interpreter_input().fill(x_test[i])" #@param {type:"string"}
  exec(script_4)
  ############################################################
  ############################################################
  #@markdown Which is the statement to invoke the interpreter?
  script_5 = "interpreter.invoke()" #@param {type:"string"}
  exec(script_5)
  ############################################################
  ############################################################
  #@markdown Which is the statement to get the output from the interpreter and save the output in `interpreter_predictions[i]`?
  script_6 = "interpreter_predictions[i] = interpreter_output()[0]"#@param {type:"string"}
  exec(script_6)
  ############################################################


# Make the shape of the y_test be the same as the predictions
y_test = np.reshape(y_test, predictions.shape)
# Make the shape of the interpreter_predictions be the same as the predictions
interpreter_predictions = np.reshape(interpreter_predictions, predictions.shape)

# %% [markdown]
# ## Plot the Result

# %%
plt.clf()
plt.title('Test data predicted vs actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted (tensorflow)')
############################################################
#@markdown Please write the statement to plot the outputs in green dots with a label `Predicted (tflite)` from the interpreter.
script = "plt.plot(x_test, interpreter_predictions, 'g.', label='Predicted (tflite)')"#@param {type:"string"}
exec(script)
############################################################
plt.legend()
plt.show()
